# %%
import pandas as pd
import numpy as np

# %%
da = pd.read_csv(r"C:\Users\RHEA TIWARI\Desktop\ida project\DatasetofSidi1.csv")


with pd.option_context('display.max_rows', None):
    display(da)
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC      DC   ISI  \
# 0      1      6  2012           32   71   12    0.7  57.1   2.5    8.20   0.6
# 1      2      6  2012           30   73   13    4.0  55.7   2.7    7.80   0.6
# 2      3      6  2012           29   80   14    2.0  48.7   2.2    7.60   0.3
# 3      4      6  2012           30   64   14    0.0  79.4   5.2   15.40   2.2
# 4      5      6  2012           32   60   14    0.2  77.1   6.0   17.60   1.8
# 5      6      6  2012           35   54   11    0.1  83.7   8.4   26.30   3.1
# 6      7      6  2012           35   44   17    0.2  85.6   9.9   28.90   5.4
# 7      8      6  2012           28   51   17    1.3  71.4   7.7    7.40   1.5
# 8      9      6  2012           27   59   18    0.1  78.1   8.5   14.70   2.4
# 9     10      6  2012           30   41   15    0.0  89.4  13.3   22.50   8.4
# 10    11      6  2012           31   42   21    0.0  90.6  18.2   30.50  13.4
# 11    12      6  2012           27   58   17    0.0  88.9  21.3   37.80   8.7
# 12    13      6  2012           30   52   15    2.0  72.3  11.4    7.80   1.4
# 13    14      6  2012           27   79   16    0.7  53.4   6.4    7.30   0.5
# 14    15      6  2012           28   90   15    0.0  66.8   7.2   14.70   1.2
# 15    16      6  2012           29   87   15    0.4  47.4   4.2    8.00   0.2
# 16    17      6  2012           31   69   17    4.7  62.2   3.9    8.00   1.1
# 17    18      6  2012           33   62   10    8.7  65.5   4.6    8.30   0.9
# 18    19      6  2012           32   67   14    4.5  64.6   4.4    8.20   1.0
# 19    20      6  2012           31   72   14    0.2  60.2   3.8    8.00   0.8
# 20    21      6  2012           32   55   14    0.0  86.2   8.3   18.40   5.0
# 21    22      6  2012           33   46   14    1.1  78.3   8.1    8.30   1.9
# 22    23      6  2012           33   59   16    0.8  74.2   7.0    8.30   1.6
# 23    24      6  2012           35   68   16    0.0  85.3  10.0   17.00   4.9
# 24    25      6  2012           34   70   16    0.0  86.0  12.8   25.60   5.4
# 25    26      6  2012           36   62   16    0.0  87.8  16.5   34.50   7.0
# 26    27      6  2012           36   55   15    0.0  89.1  20.9   43.30   8.0
# 27    28      6  2012           37   37   13    0.0  92.5  27.2   52.40  11.7
# 28    29      6  2012           37   36   13    0.6  86.2  17.9   36.70   4.8
# 29    30      6  2012           34   42   15    1.7  79.7  12.0    8.50   2.2
# 30     1      7  2012           28   58   18    2.2  63.7   3.2    8.50   1.2
# 31     2      7  2012           33   48   16    0.0  87.6   7.9   17.80   6.8
# 32     3      7  2012           34   56   17    0.1  84.7   9.7   27.30   4.7
# 33     4      7  2012           34   58   18    0.0  88.0  13.6   36.80   8.0
# 34     5      7  2012           34   45   18    0.0  90.5  18.7   46.40  11.3
# 35     6      7  2012           35   42   15    0.3  84.7  15.5   45.10   4.3
# 36     7      7  2012           38   43   13    0.5  85.0  13.0   35.40   4.1
# 37     8      7  2012           35   47   18    6.0  80.8   9.8    9.70   3.1
# 38     9      7  2012           36   43   15    1.9  82.3   9.4    9.90   3.2
# 39    10      7  2012           34   51   16    3.8  77.5   8.0    9.50   2.0
# 10   18.0  16.7        fire
# 11   21.2  12.9        fire
# 12   10.9   0.9    not fire
# 13    6.1   0.3    not fire
# 14    7.1   0.6    not fire
# 15    4.1   0.1    not fire
# 16    3.8   0.4    not fire
# 17    4.4   0.4    not fire
# 18    4.2   0.4    not fire
# 19    3.7   0.3    not fire
# 20    8.2   4.9        fire
# 21    7.7   1.2    not fire
# 22    6.7   0.8    not fire
# 23    9.9   5.3        fire
# 24   12.7   6.7        fire
# 25   16.4   9.5        fire
# 26   20.8  12.0        fire
# 27   27.1  18.4        fire
# 28   17.8   7.2        fire
# 29   11.5   2.2  not fire
# 30    3.3   0.5    not fire
# 31    7.8   6.4        fire
# 32   10.3   5.2        fire
# 33   14.1   9.9        fire
# 34   18.7  15.0        fire
# 35   16.7   6.3        fire
# 36   13.7   5.2        fire
# 37    9.4   3.0        fire
# 38    9.0   3.1        fire
# 39    7.7   1.3    not fire
# 40    6.8   0.8    not fire
# 41   12.5   9.6        fire
# 42   10.9   4.7        fire
# 43   10.4   NaN            NaN
# 44   17.7  14.1        fire
# 45   19.2   7.3        fire
# 46   20.9   7.7        fire
# 47   23.9   9.1        fire
# 48   27.7  13.0        fire
# 49   32.6  17.3        fire
# 50   39.5  30.0        fire
# 51   44.0  25.4        fire
# 52   46.5  16.3        fire
# 53   21.7   2.5    not fire
# 54   11.4   0.7    not fire
# 55   10.7   1.0    not fire
# 56   11.8   3.2    not fire
# 57   15.7   9.0        fire
# 58   19.5  10.9        fire
# 59   23.8  13.2        fire
# 60   28.3  14.5        fire
# 61    4.4   0.8    not fire
# 62   10.6  13.5        fire
# 63   16.9  19.5        fire
# 64   22.9  20.9        fire
# 65   23.5  12.6        fire
# 66   10.5   0.8    not fire
# 67    6.9   0.6    not fire
# 68   11.0   5.9        fire
# 69   16.4  12.7        fire
# 70   15.8  10.7        fire
# 71   22.4  21.6        fire
# 72   18.4  18.8        fire
# 73   17.5  10.5        fire
# 74   22.3  15.7        fire
# 75   19.0   5.5        fire
# 76   24.2  14.8        fire
# 77   30.4  24.0        fire
# 78   35.9  26.3        fire
# 79   35.5   7.7        fire
# 80   38.1   9.0        fire
# 81   41.3  12.2        fire
# 82   45.5  18.1        fire
# 83   50.2  24.5        fire
# 84   54.9  26.9        fire
# 85   59.5  31.1        fire
# 86   64.0  30.3        fire
# 87   68.0  26.1        fire
# 88   30.6   6.1    not fire
# 89   30.6   5.9        fire
# 90   35.7  16.0        fire
# 91   39.3  19.4        fire
# 92    1.4   0.0    not fire
# 93    4.0   0.8    not fire
# 94    6.0   2.5        fire
# 95    6.0   0.7    not fire
# 96    3.9   0.4    not fire
# 97    3.5   0.4    not fire
# 98    6.4   3.2        fire
# 99    8.1   2.7        fire
# 100  10.0   3.7        fire
# 101   4.6   0.3    not fire
# 102   6.6   1.2    not fire
# 103   9.1   3.9        fire
# 104  12.4  10.3        fire
# 105  14.3   5.7        fire
# 106  17.8   9.8        fire
# 107  22.4  19.3        fire
# 108  26.2  17.5        fire
# 109  28.2  15.4        fire
# 110  28.9   5.6        fire
# 111  24.4   3.8    not fire
# 112  29.4  21.6        fire
# 113  32.4  13.7        fire
# 114  36.0  15.2        fire
# 115  11.9   0.4    not fire
# 116  14.1   3.0    not fire
# 117  16.9   6.5        fire
# 118   6.2   0.0    not fire
# 119   3.4   0.2    not fire
# 120   5.1   0.7    not fire
# 121   4.8   0.5   not fire

# %% [markdown]
# there are 2 different datasets in one file so we are going have to make 2 different files and evaluate them both

# %%
df=pd.read_csv(r"C:\Users\RHEA TIWARI\Desktop\ida project\DatasetofSidi1.csv")
df
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC    DC  ISI  \
# 0      1      6  2012           32   71   12    0.7  57.1   2.5   8.2  0.6
# 1      2      6  2012           30   73   13    4.0  55.7   2.7   7.8  0.6
# 2      3      6  2012           29   80   14    2.0  48.7   2.2   7.6  0.3
# 3      4      6  2012           30   64   14    0.0  79.4   5.2  15.4  2.2
# 4      5      6  2012           32   60   14    0.2  77.1   6.0  17.6  1.8
# ..   ...    ...   ...          ...  ...  ...    ...   ...   ...   ...  ...
# 117   26      9  2012           30   65   14    0.0  85.4  16.0  44.5  4.5
# 118   27      9  2012           28   87   15    4.4  41.1   6.5   8.0  0.1
# 119   28      9  2012           27   87   29    0.5  45.9   3.5   7.9  0.4
# 120   29      9  2012           24   54   18    0.1  79.7   4.3  15.2  1.7
# 121   30      9  2012           24   64   15    0.2  67.3   3.8  16.5  1.2
#
#       BUI  FWI     Classes
# 0     2.8  0.2   not fire
# 1     2.9  0.2   not fire
# 2     2.6  0.1   not fire
# 3     5.6  1.0   not fire
# 4     6.5  0.9   not fire
# ..    ...  ...           ...
# 117  16.9  6.5       fire
# 118   6.2  0.0   not fire
# 119   3.4  0.2   not fire
# 120   5.1  0.7   not fire
# 121   4.8  0.5  not fire
#
# [122 rows x 14 columns]

# %% [markdown]
# This is the Sidi-Bel Abbes Region Dataset
# RH: Relative Humidity.
# Ws: Wind speed.
# Rain: Amount of rain or precipitation.
# FFMC: Fine Fuel Moisture Code.
# DMC: Duff Moisture Code.
# DC: Drought Code.
# ISI: Initial Spread Index.
# BUI: Buildup Index.
# FWI: Fire Weather Index.

# %%
df.shape
# Out:
# (122, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          122 non-null    int64
#  1   month        122 non-null    int64
#  2   year         122 non-null    int64
#  3   Temperature  122 non-null    int64
#  4    RH          122 non-null    int64
#  5    Ws          122 non-null    int64
#  6   Rain         122 non-null    float64
#  7   FFMC         122 non-null    float64
#  8   DMC          122 non-null    float64
#  9   DC           122 non-null    float64
#  10  ISI          122 non-null    float64
#  11  BUI          122 non-null    float64
#  12  FWI          121 non-null    float64
#  13  Classes      121 non-null    object
# dtypes: float64(7), int64(6), object(1)
# memory usage: 13.5+ KB

# %% [markdown]
# There is an empty value in FWI

# %% [markdown]
# Viewing basic statistics about the Sidi-Bel Abbes region forest fires

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  122.000000  122.000000   122.0   122.000000  122.000000  122.000000
# mean    15.754098    7.500000  2012.0    33.163934   55.901639   15.008197
# std      8.843274    1.115259     0.0     3.675608   15.716186    2.692186
# min      1.000000    6.000000  2012.0    24.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   43.250000   14.000000
# 50%     16.000000    7.500000  2012.0    34.000000   56.000000   15.000000
# 75%     23.000000    8.000000  2012.0    36.000000   66.750000   16.750000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#             Rain         FFMC         DMC          DC         ISI         BUI  \
# count  122.000000  122.000000  122.000000  122.000000  122.000000  122.000000
# mean     0.678689   81.102459   17.031967   45.416311    5.892623   17.903279
# std      1.486759   12.244064   12.995068   42.927028    4.832913   13.878868
# min      0.000000   37.900000    0.900000    7.300000    0.100000    1.400000
# 25%      0.000000   77.650000    7.325000   14.700000    1.825000    7.400000
# 50%      0.000000   84.850000   13.150000   31.500000    4.600000   13.900000
# 75%      0.475000   89.275000   22.900000   56.975000    8.625000   23.875000
# max      8.700000   96.000000   65.900000  177.300000   19.000000   68.000000
#
#               FWI
# count  121.000000
# mean     8.504959
# std      8.169444
# min      0.000000
# 25%      0.900000
# 50%      6.000000
# 75%     13.700000
# max     31.100000

# %% [markdown]
# Looking at the data in "Classes" we can predict the occurrence of fires based on weather conditions and environmental factors.Here we ca see that forest fires occured 79 of the 122 times data was recorded.

# %%
data_df=pd.read_csv(r"C:\Users\RHEA TIWARI\Desktop\ida project\BejaiaDataset.csv")
data_df
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  \
# 0      1      6  2012           29   57   18    0.0  65.7  3.4   7.6  1.3
# 1      2      6  2012           29   61   13    1.3  64.4  4.1   7.6  1.0
# 2      3      6  2012           26   82   22   13.1  47.1  2.5   7.1  0.3
# 3      4      6  2012           25   89   13    2.5  28.6  1.3   6.9  0.0
# 4      5      6  2012           27   77   16    0.0  64.8  3.0  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...  ...   ...  ...
# 117   26      9  2012           31   54   11    0.0  82.0  6.0  16.3  2.5
# 118   27      9  2012           31   66   11    0.0  85.7  8.3  24.9  4.0
# 119   28      9  2012           32   47   14    0.7  77.5  7.1   8.8  1.8
# 120   29      9  2012           26   80   16    1.8  47.4  2.9   7.7  0.3
# 121   30      9  2012           25   78   14    1.4  45.0  1.9   7.5  0.2
#
#      BUI  FWI    Classes
# 0    3.4  0.5    not fire
# 1    3.9  0.4   not fire
# 2    2.7  0.1  not fire
# 3    1.7  0.0  not fire
# 4    3.9  0.5  not fire
# ..   ...  ...          ...
# 117  6.2  1.7   not fire
# 118  9.0  4.1         fire
# 119  6.8  0.9   not fire
# 120  3.0  0.1  not fire
# 121  2.4  0.1   not fire
#
# [122 rows x 14 columns]

# %% [markdown]
# 	This is the Bejaia Region Dataset

# %%
data_df.shape
# Out:
# (122, 14)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          122 non-null    int64
#  1   month        122 non-null    int64
#  2   year         122 non-null    int64
#  3   Temperature  122 non-null    int64
#  4    RH          122 non-null    int64
#  5    Ws          122 non-null    int64
#  6   Rain         122 non-null    float64
#  7   FFMC         122 non-null    float64
#  8   DMC          122 non-null    float64
#  9   DC           122 non-null    float64
#  10  ISI          122 non-null    float64
#  11  BUI          122 non-null    float64
#  12  FWI          122 non-null    float64
#  13  Classes      122 non-null    object
# dtypes: float64(7), int64(6), object(1)
# memory usage: 13.5+ KB

# %%
data_df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  122.000000  122.000000   122.0   122.000000  122.000000  122.000000
# mean    15.754098    7.500000  2012.0    31.180328   67.975410   16.000000
# std      8.843274    1.115259     0.0     3.320401   11.154411    2.848807
# min      1.000000    6.000000  2012.0    22.000000   45.000000   11.000000
# 25%      8.000000    7.000000  2012.0    29.000000   60.000000   14.000000
# 50%     16.000000    7.500000  2012.0    31.000000   68.000000   16.000000
# 75%     23.000000    8.000000  2012.0    34.000000   77.750000   18.000000
# max     31.000000    9.000000  2012.0    37.000000   89.000000   26.000000
#
#             Rain         FFMC         DMC          DC         ISI         BUI  \
# count  122.000000  122.000000  122.000000  122.000000  122.000000  122.000000
# mean     0.842623   74.672951   12.314754   53.160656    3.655738   15.426230
# std      2.409208   15.558713   11.274360   51.778265    3.021768   14.474302
# min      0.000000   28.600000    0.700000    6.900000    0.000000    1.100000
# 25%      0.000000   65.925000    3.725000   10.050000    1.125000    5.100000
# 50%      0.000000   80.900000    9.450000   35.550000    2.650000   11.200000
# 75%      0.500000   86.775000   16.300000   79.025000    5.600000   21.675000
# max     16.800000   90.300000   54.200000  220.400000   12.500000   67.400000
#
#               FWI
# count  122.000000
# mean     5.577869
# std      6.343051
# min      0.000000
# 25%      0.500000
# 50%      3.000000
# 75%      8.700000
# max     30.200000

# %%
data_df.iloc[:,[13]].value_counts()
# Out:
# Classes
# fire           58
# not fire       26
# not fire       14
# not fire       13
# not fire       10
# fire            1
# dtype: int64

# %% [markdown]
# Here forest fires occured 59 of the 122 recorded observations.

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('whitegrid')

matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)

# %%
list(df)
# Out:
# ['day',
#  'month',
#  'year',
#  'Temperature',
#  ' RH',
#  ' Ws',
#  'Rain ',
#  'FFMC',
#  'DMC',
#  'DC',
#  'ISI',
#  'BUI',
#  'FWI',
#  'Classes  ']

# %%
type(data_df['Classes  '])
# Out:
# pandas.core.series.Series

# %%
plt.plot(data_df['Classes  '],data_df.Temperature);

# %%
plt.bar(df['Classes  '],df.Temperature);
plt.plot(df['Classes  '],df.Temperature,'o--r');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27104\460560290.py in <module>
# ----> 1 plt.bar(df['Classes  '],df.Temperature);
#       2 plt.plot(df['Classes  '],df.Temperature,'o--r');
#       3
#
# ~\.conda\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2397         x, height, width=0.8, bottom=None, *, align='center',
#    2398         data=None, **kwargs):
# -> 2399     return gca().bar(
#    2400         x, height, width=width, bottom=bottom, align=align,
#    2401         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\.conda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\.conda\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2315
#    2316         if orientation == 'vertical':
# -> 2317             self._process_unit_info(
#    2318                 [("x", x), ("y", height)], kwargs, convert=False)
#    2319             if log:
#
# ~\.conda\lib\site-packages\matplotlib\axes\_base.py in _process_unit_info(self, datasets, kwargs, convert)
#    2524             # Update from data if axis is already set but no unit is set yet.
#    2525             if axis is not None and data is not None and not axis.have_units():
# -> 2526                 axis.update_units(data)
#    2527         for axis_name, axis in axis_map.items():
#    2528             # Return if no axis is set.
#
# ~\.conda\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1447         neednew = self.converter != converter
#    1448         self.converter = converter
# -> 1449         default = self.converter.default_units(data, self)
#    1450         if default is not None and self.units is None:
#    1451             self.set_units(default)
#
# ~\.conda\lib\site-packages\matplotlib\category.py in default_units(data, axis)
#     114         # the conversion call stack is default_units -> axis_info -> convert
#     115         if axis.units is None:
# --> 116             axis.set_units(UnitData(data))
#     117         else:
#     118             axis.units.update(data)
#
# ~\.conda\lib\site-packages\matplotlib\category.py in __init__(self, data)
#     190         self._counter = itertools.count()
#     191         if data is not None:
# --> 192             self.update(data)
#     193
#     194     @staticmethod
#
# ~\.conda\lib\site-packages\matplotlib\category.py in update(self, data)
#     225         for val in OrderedDict.fromkeys(data):
#     226             # OrderedDict just iterates over unique values in data.
# --> 227             _api.check_isinstance((str, bytes), value=val)
#     228             if convertible:
#     229                 # this will only be called so long as convertible is True.
#
# ~\.conda\lib\site-packages\matplotlib\_api\__init__.py in check_isinstance(_types, **kwargs)
#      91                 names.remove("None")
#      92                 names.append("None")
# ---> 93             raise TypeError(
#      94                 "{!r} must be an instance of {}, not a {}".format(
#      95                     k,
#
# TypeError: 'value' must be an instance of str or bytes, not a float

# %%
c = []
count=0
for index, row in df.iterrows():
    if row['Classes  '] == 'fire   ':
        c.append(row['Temperature'])
        count=count+1
print(c)        
from statistics import mean 
print(mean(c))

for i in c:
    if(i<30):
        print(i)

# %%
plt.plot(df['Classes  '].head(79),c,'o--r')
plt.bar(df['Classes  '].head(79),c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27104\4096075692.py in <module>
# ----> 1 plt.plot(df['Classes  '].head(79),c,'o--r')
#       2 plt.bar(df['Classes  '].head(79),c)
#
# ~\.conda\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\.conda\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~\.conda\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~\.conda\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     491
#     492         if self.axes.xaxis is not None:
# --> 493             self.axes.xaxis.update_units(x)
#     494         if self.axes.yaxis is not None:
#     495             self.axes.yaxis.update_units(y)
#
# ~\.conda\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1447         neednew = self.converter != converter
#    1448         self.converter = converter
# -> 1449         default = self.converter.default_units(data, self)
#    1450         if default is not None and self.units is None:
#    1451             self.set_units(default)
#
# ~\.conda\lib\site-packages\matplotlib\category.py in default_units(data, axis)
#     114         # the conversion call stack is default_units -> axis_info -> convert
#     115         if axis.units is None:
# --> 116             axis.set_units(UnitData(data))
#     117         else:
#     118             axis.units.update(data)
#
# ~\.conda\lib\site-packages\matplotlib\category.py in __init__(self, data)
#     190         self._counter = itertools.count()
#     191         if data is not None:
# --> 192             self.update(data)
#     193
#     194     @staticmethod
#
# ~\.conda\lib\site-packages\matplotlib\category.py in update(self, data)
#     225         for val in OrderedDict.fromkeys(data):
#     226             # OrderedDict just iterates over unique values in data.
# --> 227             _api.check_isinstance((str, bytes), value=val)
#     228             if convertible:
#     229                 # this will only be called so long as convertible is True.
#
# ~\.conda\lib\site-packages\matplotlib\_api\__init__.py in check_isinstance(_types, **kwargs)
#      91                 names.remove("None")
#      92                 names.append("None")
# ---> 93             raise TypeError(
#      94                 "{!r} must be an instance of {}, not a {}".format(
#      95                     k,
#
# TypeError: 'value' must be an instance of str or bytes, not a float
